# %%
from astropy.io import fits

from roman_fits_utils import fix_hdr

import os
# os.chdir("/Users/keith/astr/research_astr/summer-roman-project/FOV0_extraction/fits")

filename = "/Users/keith/astr/research_astr/summer-roman-project/FOV0_extraction/fits/model_slitless_GRS_FOV0_roll5_dx0_dy0_SCA1_direct_final.fits"

# %%
model_fits = fits.open(filename)

# %%
hdr_dict = {"ra": "0;%f"%model_fits[1].header["RA_APER"],
            "dec": "0;%f"%model_fits[1].header["DEC_APER"]}

# %%
fix_hdr(filename, filename, hdr_dict)
# Out:
# 0

# %%
fix_hdr?
# Out:
# Signature: fix_hdr(filename, new_filename, hdr_dict, overwrite=True)
# Docstring:
# Function that adds/changes header information according to a supplied dictionary.
#
# Parameters
#     ----------
#     filename: str
#             Name of the fits file to be altered.
#
# new_filename: str
#     Name the altered file will be saved as.
#
# hdr_dict: dict
#     Python dictionary of new/altered header information. Should be formation as {hdr_key: ext;hdr_value}.
#     This way the dictionary value can be split at the semi-colon into the fits extension where the header
#     data is the be changed and the appropriate value for that change.
#
# overwrite: bool, optional
#     If new_filename already exists, should it be overwritten? default=True
# File:      ~/astr/research_astr/summer-roman-project/FOV0_extraction/notebooks/roman_fits_utils.py
# Type:      function
