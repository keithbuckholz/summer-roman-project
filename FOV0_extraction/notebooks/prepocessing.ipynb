# %%
import glob
import time
import os

import numpy as np
import matplotlib.pyplot as plt

from astropy.io import fits
import drizzlepac

import grizli
from grizli import utils, multifit

os.chdir("../fits")
# Out:
# The following task in the stsci.skypac package can be run with TEAL:
#                                     skymatch
# The following tasks in the drizzlepac package can be run with TEAL:
#     astrodrizzle       config_testbed      imagefindpars           mapreg
#        photeq            pixreplace           pixtopix            pixtosky
#   refimagefindpars       resetbits          runastrodriz          skytopix
#      tweakback            tweakreg           updatenpol

# %%
files = glob.glob('ready*.fits') + glob.glob("model*.fits")
info = grizli.utils.get_flt_info(files)
visits, filters = grizli.utils.parse_flt_files(info=info, uniquename=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 files = glob.glob('ready*.fits') + glob.glob("model*.fits")
#       2 info = grizli.utils.get_flt_info(files)
# ----> 3 visits, filters = grizli.utils.parse_flt_files(info=info, uniquename=True)
#
# File ~/miniconda3/envs/grizli_env/lib/python3.12/site-packages/grizli/utils.py:816, in parse_flt_files(files, info, uniquename, use_visit, get_footprint, translate, visit_split_shift, max_dt, path)
#     813 info['progIDs'] = _prog_ids
#     815 progIDs = np.unique(info['progIDs'])
# --> 816 dates = np.array([''.join(date.split('-')[1:])
#     817                   for date in info['date-obs']])
#     819 targets = np.unique(target_list)
#     821 output_list = []  # OrderedDict()
#
# AttributeError: 'numpy.float64' object has no attribute 'split'

# %%
from grizli.prep import process_direct_grism_visit
