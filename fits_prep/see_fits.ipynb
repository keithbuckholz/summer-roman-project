# %%
from astropy.io import fits

import os
os.chdir("../FOV0_extraction/copying_pipeline/FOV0/RAW")

# %%
example_fits = fits.open("/Users/keith/astr/research_astr/summer-roman-project/pipeline/j033216m2743/RAW/ib6o21qmq_flt.fits")
explore_fits = fits.open("model_slitless_GRS_FOV0_roll5_dx0_dy0_SCA1_direct_final_flt.fits")

# %%
explore_fits[1].header
# Out:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 4088
# NAXIS2  =                 4088
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# EXTNAME = 'SCI     '           / Extension name
# INHERIT =                    F / Inherits global header
# DATE    = '2021-09-15T18:01:08' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# IRAF-TLM= '2021-09-15T18:01:02' / Time of last modification
# OBJECT  = 'aXeSIM simulation'  / Name of the object observed
# WCSAXES =                    2 / number of World Coordinate System axes
# CRPIX1  =                512.0 / x-coordinate of reference pixel
# CRPIX2  =                512.0 / y-coordinate of reference pixel
# ...

# %%
example_fits[1].header
# Out:
# XTENSION= 'IMAGE   '           / IMAGE extension
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 1014 / length of data axis 1
# NAXIS2  =                 1014 / length of data axis 2
# PCOUNT  =                    0 / required keyword; must = 0
# GCOUNT  =                    1 / required keyword; must = 1
# ORIGIN  = 'HSTIO/CFITSIO March 2010' / FITS file originator
# DATE    = '2024-06-28' / date this file was written (yyyy-mm-dd)
# INHERIT =                    T / inherit the primary header
# EXTNAME = 'SCI     '           / extension name
# EXTVER  =                    1 / extension version number
# ROOTNAME= 'ib6o21qmq                         ' / rootname of the observation set
# EXPNAME = 'ib6o21qmq                ' / exposure identifier
# BUNIT   = 'ELECTRONS/S'        / brightness units
#
#               / World Coordinate System and Related Parameters
#
# ...
