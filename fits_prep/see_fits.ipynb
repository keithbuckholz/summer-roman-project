# %%
from astropy.io import fits

import os
os.chdir("../FOV0_extraction/copying_pipeline/FOV0/RAW")

# %%
example_fits = fits.open("/Users/keith/astr/research_astr/summer-roman-project/pipeline/j033216m2743/RAW/ib6o21qmq_flt.fits")

# %%
explore_fits = fits.open("model_slitless_GRS_FOV0_roll0_dx0_dy0_SCA1_direct_final_flt.fits")

# %%
explore_fits[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# INSTRUME= 'ROMAN   '           / instrument name
# EXPTIME =                141.0 / exposure time
# FILTER  = 'det1    '
# RA      = '53.224911'
# DEC     = '-27.823501'
# DATE-OBS= '2021-09-15'
# EXPSTART= '5.510751905405E+04'
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H

# %%
example_fits[0].header["*OBS*"]
# Out:
# DATE-OBS= '2009-10-03'         / UT date of start of observation (yyyy-mm-dd)
# TIME-OBS= '11:32:21'           / UT time of start of observation (hh:mm:ss)
# OBSTYPE = 'SPECTROSCOPIC '     / observation type - imaging or spectroscopic
# OBSMODE = 'MULTIACCUM'         / operating mode
