# %% [markdown]
# ## Use stenv (environment with old photutils)
#
# Explicitly calling photutils_detection with use_seg=True give the same results as just running the sim with a seg_file, but providing no catalog.

# %%
# Imports
import grizli
import grizli.model

import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import os

os.chdir("/Users/keith/astr/research_astr/summer-roman-project/FOV0_sims/fits")
direct_file = "rotated_direct.fits"
seg_file = "seg.fits"

# %%
pad = 100
roman_sim = grizli.model.GrismFLT(direct_file=direct_file,
                                  seg_file=seg_file, pad=pad)
# Out:
# Image cutout: x=slice(0, 4088, None), y=slice(0, 4088, None) [Out of range]
# rotated_direct.fits / Pad ref HDU with 264 pixels
# rotated_direct.fits / blot segmentation seg.fits[0]
# The following task in the stsci.skypac package can be run with TEAL:
#                                     skymatch
# The following tasks in the drizzlepac package can be run with TEAL:
#     astrodrizzle       config_testbed      imagefindpars           mapreg
#        photeq            pixreplace           pixtopix            pixtosky
#   refimagefindpars       resetbits          runastrodriz          skytopix
#      tweakback            tweakreg           updatenpol
# Using default C-based coordinate transformation...
# Using default C-based coordinate transformation...

# %%
## Make a simple detection catalog + segmentation image with photutils.
roman_sim.photutils_detection(detect_thresh=2, grow_seg=0, gauss_fwhm=2., 
                             verbose=True, save_detection=True, use_seg=True)
# Out:
# rotated_direct: photutils.source_properties
# WARNING: AstropyDeprecationWarning: The source_properties function is deprecated and may be removed in a future version.
#         Use `~photutils.segmentation.SourceCatalog` instead. [grizli.utils]
# WARNING: AstropyDeprecationWarning: The SourceProperties class is deprecated and may be removed in a future version.
#         Use `~photutils.segmentation.SourceCatalog` instead. [photutils.segmentation.properties]
# WARNING: AstropyDeprecationWarning: The LegacySourceCatalog class is deprecated and may be removed in a future version.
#         Use `~photutils.segmentation.SourceCatalog` instead. [photutils.segmentation.properties]
# Rename column: xcentroid -> x_flt
# Rename column: ycentroid -> y_flt
# rotated_direct: photutils.source_properties - 7679 objects
# rotated_direct: save rotated_direct.detect_seg.fits, rotated_direct.detect.cat
# True

# %%
roman_sim.compute_full_model(mag_limit=28, size=76, compute_size=False)

# %%
plt.imshow(roman_sim.model[pad:-pad, pad:-pad]/np.max(roman_sim.model), interpolation='Nearest', 
           origin='lower', vmin=0., vmax=0.01, cmap='hot')
plt.title("photutils_detections using our seg map")
# Out:
# Text(0.5, 1.0, 'photutils_detections using our seg map')

# %%
raise Exception("Pause before saving")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 raise Exception("Pause before saving")
#
# Exception: Pause before saving

# %%
header = fits.open(direct_file)[1].header
fits.writeto("basic_model.fits", roman_sim.model[pad:-pad, pad:-pad], header=header, overwrite=True)
