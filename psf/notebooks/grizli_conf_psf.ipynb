# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits

# %%
file = fits.open("/Users/keith/GRIZLI/CONF/extended_PSF_F160W.fits")
data = file[0].data
file.close()

# %%
plt.imshow(data, origin='lower')
